# %%
import io, os
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import platform
import sys
from glob import glob
from collections import Counter

pd.set_option("display.max_columns", None)

from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
year = 2022
month = "03"


def is_databricks():
    return True if "DATABRICKS_RUNTIME_VERSION" in os.environ else False


running_on = platform.system()

if running_on == "Windows":
    path = fr"C:\Users\\pmm\\ownCloud\\jupyter\\22-05 HR"
elif running_on == "Darwin":
    path = f"/Users/pmm/ownCloud/jupyter/22-05 HR"
elif "google.colab" in str(get_ipython()):
    path = "/content"
elif is_databricks():
    my_container = "projects"
    my_lake = "tdsdsdatalake"
    mount_point = f"/mnt/{my_container}"
    path = f"{mount_point}"

    configs = {
        "fs.azure.account.auth.type": "CustomAccessToken",
        "fs.azure.account.custom.token.provider.class": spark.conf.get(
            "spark.databricks.passthrough.adls.gen2.tokenProviderClassName"
        ),
    }

    if not any(
        mount.mountPoint == mount_point for mount in dbutils.fs.mounts()
    ):
        dbutils.fs.mount(
            source=f"abfss://{my_container}@{my_lake}.dfs.core.windows.net/",
            mount_point=mount_point,
            extra_configs=configs,
        )


# data_file = os.path.join(path, "Internal Movement for DS FINAL.csv")

# %%
if is_databricks():
    data_file = os.path.join(path, "Internal Movement for DS FINAL.csv")
    df_orig = (
        spark.read.option("header", "true")
        .option("inferSchema", "true")
        .csv(data_file)
        .select("*")
        .toPandas()
    )
else:
    data_file = os.path.join(path, "Internal Movement for DS FINAL.xlsx")
    df_orig = pd.read_excel(os.path.join(data_file))

# %%
dtypes = {
    "pers_no": "object",
    "job_key": "object",
    "position": "object",
    "job_abbrev": "object",
    "contract": "object",
    "act": "object",
    "reason": "int64",
    "start_date": "datetime64[ns]",
    "most_recent_hire_date_01": "datetime64[ns]",
    "service_anniversary_16": "datetime64[ns]",
    "cocd": "object",
    "org_unit": "object",
    "employee_group": "object",
    "employee_subgroup": "object",
    "commission_type": "object",
    "pay_scale_group_effective_date": "datetime64[ns]",
    "ps_group": "object",
    "prev_ps_group": "object",
    "annl_sal_hrly_wage": "float64",
    "annual_salary": "float64",
    "pay_level_midpoint": "float64",
    "prev_wage": "float64",
    "pts": "int64",
    "supervisor": "object",
    "ps_area": "object",
    "aap": "object",
    "city": "object",
    "state": "object",
    "generation": "object",
    "retiree_medical_eligibility": "object",
    "functional_area": "object",
    "fst": "object",
    "age_at_action": "float64",
    "percent_of_market_after_action": "float64",
    "percent_of_market_before_action": "float64",
    "hired": "object",
    "term": "object",
    "retirement": "object",
    "promotion": "object",
    "progression": "object",
    "previous_job_code": "object",
    "current_bu": "object",
    "previous_bu": "object",
    "gender_most_current": "object",
    "race_ethinicity_most_current": "object",
    "poc_non_poc_most_current": "object",
    "tds_vet_excludes_v1_v9_most_current": "object",
    "disabled_most_current": "object",
    "tds_vet_excludes_v1_v9_most_current": "object",
}

# %%
df = df_orig.copy()
df.columns = (
    df.columns.str.lower()
    .str.replace("^\s", "", regex=True)
    .str.replace("[\s.]", "_", regex=True)
    .str.replace("[^0-9a-zA-Z]", "_", regex=True)
    .str.replace("_+", "_", regex=True)
    .str.replace("_$", "", regex=True)
)

df = df.astype(dtypes)

# %%
df = df.sort_values(
    by=["pers_no", "start_date"], ascending=False, ignore_index=True
)

# %%
# ZA = new hire
# ZB - rehire

cond = ((df["act"] == "ZA") | (df["act"] == "ZB")) & (df["reason"] == 1)

df["previous_job_code"] = np.where(cond, 0, df["previous_job_code"])
df["previous_bu"] = np.where(cond, "NEW HIRE", df["previous_bu"])
df["prev_ps_group"] = np.where(cond, "NEW HIRE", df["prev_ps_group"])

# %%
# rows with na for supervisor where supervisor is the same value in row prior and after
df["pers_no_before"] = df["pers_no"].shift(1)
df["pers_no_after"] = df["pers_no"].shift(-1)
df["supervisor_before"] = df["supervisor"].shift(1)
df["supervisor_after"] = df["supervisor"].shift(-1)

df["supervisor"] = np.where(
    (
        (df["supervisor"].isnull())
        & (df["pers_no_before"] == df["pers_no_after"])
        & (df["supervisor_before"] == df["supervisor_after"])
    ),
    df["supervisor_before"],
    df["supervisor"],
)

df = df.drop(
    columns=[
        "pers_no_before",
        "pers_no_after",
        "supervisor_before",
        "supervisor_after",
    ]
)

# %%
# Male = 0
# Female = 1
# No non-binary in this dataset
df["gender"] = np.where((df["gender_most_current"] == "Male"), 0, np.nan)
df["gender"] = np.where(
    (df["gender_most_current"] == "Female"), 1, df["gender"]
)

assert df["gender"].isnull().sum() == 0  # no non-binary in dataset

# %%
# Non-Exempt Hourly = 0
# Exempt Salaried = 1
df["emp_subgroup"] = np.where(
    (df["employee_subgroup"] == "Non-Exempt Hourly"), 0, np.nan
)
df["emp_subgroup"] = np.where(
    (df["employee_subgroup"] == "Exempt Salaried"), 1, df["emp_subgroup"]
)

assert df["emp_subgroup"].isnull().sum() == 0

# %%
# NC = 0
# CO = 1
df["commission"] = np.where((df["commission_type"] == "NC"), 0, np.nan)
df["commission"] = np.where(
    (df["commission_type"] == "CO"), 1, df["commission"]
)

assert df["commission"].isnull().sum() == 0

# %%
assert df["fst"].isnull().sum() == 0
df["fst_bool"] = np.where((df["fst"] == "Yes"), 1, 0)

# %%
assert df["urg_most_current"].isnull().sum() == 0
df["urg_current"] = np.where((df["urg_most_current"] == "Yes"), 1, 0)

# %%
# X or NaN
df["retiree_med"] = np.where((df["retiree_medical_eligibility"] == "X"), 1, 0)

# %%
# x or NaN
df["progression_bool"] = np.where((df["progression"] == "x"), 1, 0)

# %%
# x or NaN
df["promotion_bool"] = np.where((df["promotion"] == "x"), 1, 0)

# %%
# x or NaN
df["retirement_bool"] = np.where((df["retirement"] == "x"), 1, 0)

# %%
# x or NaN
df["term_bool"] = np.where((df["term"] == "x"), 1, 0)

# %%
# x or NaN
df["hired_bool"] = np.where((df["hired"] == "x"), 1, 0)

# %%
df = df.drop(
    columns=[
        "gender_most_current",
        "employee_subgroup",
        "commission_type",
        "fst",
        "urg_most_current",
        "retiree_medical_eligibility",
        "progression",
        "promotion",
        "retirement",
        "term",
        "hired",
    ]
)

# %%
# #feature engineering - check that variables are calculated correctly
# #number of years at TDS
df["Time_In_TDS"] = (
    datetime.now() - df.most_recent_hire_date_01
) / np.timedelta64(1, "Y")

# %%
# #number of years on team
# df["Time_In_Team"] = (datetime.now() - df.start_date) / np.timedelta64(1, "Y")

# %%
# #number of years in payscale
df["Time_In_Payscale"] = (
    datetime.now() - df.pay_scale_group_effective_date
) / np.timedelta64(1, "Y")

# %%
df["time_since_last_event"] = np.nan

# number of years since last event
for idx, row in enumerate(df.itertuples()):
    curr_pers_no, curr_start_date = row.pers_no, row.start_date

    if idx == 0:
        prev_pers_no, prev_start_date = row.pers_no, row.start_date
        df.loc[idx, "time_since_last_event"] = 0

    if curr_pers_no == prev_pers_no:
        df.loc[idx, "time_since_last_event"] = (
            prev_start_date - curr_start_date
        ) / np.timedelta64(1, "Y")
    else:
        df.loc[idx, "time_since_last_event"] = 0

    prev_pers_no, prev_start_date = curr_pers_no, curr_start_date

# %%
# uncontrollable churn == 0
uncontrollable = [16, 23, 32, 36, 37, 47]
mask = (df["act"] == "ZI") & (~df["reason"].isin(uncontrollable))
df["churned"] = np.where(mask, 1, 0)

# %%
# df[(df["percent_of_market_after_action"] == df["percent_of_market_after_action"]) & (df["churned"] == 1)]

# %%
# salary and percent_of_market_after_action at churn drops to 0, recover
# actual salary and percent_of_market_after_action when churned

df = df.sort_values(by=["pers_no", "start_date"], ascending=True,)
df["salary_when_churned"] = np.nan


for row in df.itertuples(index=True):
    idx, curr_pers_no, curr_salary, churned = (
        row.Index,
        row.pers_no,
        row.annual_salary,
        row.churned,
    )

    if idx == 0:
        prev_pers_no, prev_salary = row.pers_no, row.annual_salary

    if (curr_pers_no == prev_pers_no) and (churned == 1):
        df.loc[idx, "salary_when_churned"] = prev_salary

    # else:
    #     df.loc[idx, "salary_when_churned"] = np.nan

    prev_pers_no, prev_salary = curr_pers_no, curr_salary

df = df.sort_values(by=["pers_no", "start_date"], ascending=False,)

df["annual_salary"] = np.where(
    df["churned"] == 1, df["salary_when_churned"], df["annual_salary"]
)
df = df.drop(columns=["salary_when_churned"])

df["percent_of_market_after_action"] = np.where(
    df["churned"] == 1,
    df["percent_of_market_before_action"],
    df["percent_of_market_after_action"],
)

# %%
# df = df.drop(columns=["percent_of_market_before_action"])

# %%
print(f"Distribution of target feature\n{df['churned'].value_counts()}")
# Out:
# Distribution of target feature
# 0    22032
# 1      831
# Name: churned, dtype: int64

# %%
# print(
#     f"Number of rows: {df.shape[0]};  Number of columns: {df.shape[1]}; No of missing values: {sum(df.isnull().sum())}"
# )

# %%
num_nans = (
    df.loc[:, (df.isnull().sum() > 0)]
    .isnull()
    .sum()
    .sort_values(ascending=False)
)

if len(num_nans) > 0:
    print("Number of misssing values by feature (nonzero)")
    num_nans.to_frame(name="NaNs").style.set_properties(
        **{
            "background-color": "white",
            "color": "darkred",
            "border-color": "dark",
        }
    )
else:
    print("No missing values in data")
# Out:
# Number of misssing values by feature (nonzero)
# <style type="text/css">
# #T_04c34_row0_col0, #T_04c34_row1_col0, #T_04c34_row2_col0, #T_04c34_row3_col0, #T_04c34_row4_col0, #T_04c34_row5_col0, #T_04c34_row6_col0, #T_04c34_row7_col0 {
#   background-color: white;
#   color: darkred;
#   border-color: dark;
# }
# </style>
# <table id="T_04c34_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NaNs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04c34_level0_row0" class="row_heading level0 row0" >percent_of_market_after_action</th>
#       <td id="T_04c34_row0_col0" class="data row0 col0" >1481</td>
#     </tr>
#     <tr>
#       <th id="T_04c34_level0_row1" class="row_heading level0 row1" >percent_of_market_before_action</th>
#       <td id="T_04c34_row1_col0" class="data row1 col0" >1481</td>
#     </tr>
#     <tr>
#       <th id="T_04c34_level0_row2" class="row_heading level0 row2" >supervisor</th>
#       <td id="T_04c34_row2_col0" class="data row2 col0" >543</td>
#     </tr>
#     <tr>
#       <th id="T_04c34_level0_row3" class="row_heading level0 row3" >prev_ps_group</th>
#       <td id="T_04c34_row3_col0" class="data row3 col0" >451</td>
#     </tr>
#     <tr>
#       <th id="T_04c34_level0_row4" class="row_heading level0 row4" >annual_salary</th>
#       <td id="T_04c34_row4_col0" class="data row4 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_04c34_level0_row5" class="row_heading level0 row5" >aap</th>
#       <td id="T_04c34_row5_col0" class="data row5 col0" >22</td>
#     </tr>
#     <tr>
#       <th id="T_04c34_level0_row6" class="row_heading level0 row6" >previous_job_code</th>
#       <td id="T_04c34_row6_col0" class="data row6 col0" >13</td>
#     </tr>
#     <tr>
#       <th id="T_04c34_level0_row7" class="row_heading level0 row7" >previous_bu</th>
#       <td id="T_04c34_row7_col0" class="data row7 col0" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
# print("Info about the data types:")
# dict(Counter(df.dtypes.values))

# %%
frac = 1
# df.sample(frac=frac, axis=1).describe().T

df.sample(frac=frac, axis=1).describe().T.style.bar(
    subset=["mean"], color="lightblue"
).background_gradient(subset=["std"], cmap="Reds").background_gradient(
    subset=["50%"], cmap="coolwarm"
)
# Out:
# <style type="text/css">
# #T_f5567_row0_col1, #T_f5567_row1_col1, #T_f5567_row2_col1, #T_f5567_row3_col1, #T_f5567_row4_col1, #T_f5567_row7_col1, #T_f5567_row9_col1, #T_f5567_row10_col1, #T_f5567_row11_col1, #T_f5567_row13_col1, #T_f5567_row14_col1, #T_f5567_row15_col1, #T_f5567_row16_col1, #T_f5567_row17_col1, #T_f5567_row19_col1, #T_f5567_row20_col1, #T_f5567_row21_col1, #T_f5567_row23_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 0.0%, transparent 0.0%);
# }
# #T_f5567_row0_col2, #T_f5567_row1_col2, #T_f5567_row2_col2, #T_f5567_row3_col2, #T_f5567_row4_col2, #T_f5567_row7_col2, #T_f5567_row8_col2, #T_f5567_row9_col2, #T_f5567_row10_col2, #T_f5567_row11_col2, #T_f5567_row13_col2, #T_f5567_row14_col2, #T_f5567_row15_col2, #T_f5567_row16_col2, #T_f5567_row17_col2, #T_f5567_row18_col2, #T_f5567_row19_col2, #T_f5567_row20_col2, #T_f5567_row21_col2, #T_f5567_row23_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f5567_row0_col5, #T_f5567_row1_col5, #T_f5567_row2_col5, #T_f5567_row3_col5, #T_f5567_row4_col5, #T_f5567_row5_col5, #T_f5567_row7_col5, #T_f5567_row8_col5, #T_f5567_row9_col5, #T_f5567_row10_col5, #T_f5567_row11_col5, #T_f5567_row12_col5, #T_f5567_row13_col5, #T_f5567_row14_col5, #T_f5567_row15_col5, #T_f5567_row16_col5, #T_f5567_row17_col5, #T_f5567_row18_col5, #T_f5567_row19_col5, #T_f5567_row20_col5, #T_f5567_row21_col5, #T_f5567_row22_col5, #T_f5567_row23_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f5567_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 54.7%, transparent 54.7%);
# }
# #T_f5567_row5_col2 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_f5567_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
# }
# #T_f5567_row6_col2 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_f5567_row6_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f5567_row8_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_f5567_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 59.5%, transparent 59.5%);
# }
# #T_f5567_row12_col2 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# #T_f5567_row18_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
# }
# #T_f5567_row22_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 67.3%, transparent 67.3%);
# }
# #T_f5567_row22_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f5567_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5567_level0_row0" class="row_heading level0 row0" >fst_bool</th>
#       <td id="T_f5567_row0_col0" class="data row0 col0" >22863.000000</td>
#       <td id="T_f5567_row0_col1" class="data row0 col1" >0.238201</td>
#       <td id="T_f5567_row0_col2" class="data row0 col2" >0.425992</td>
#       <td id="T_f5567_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f5567_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f5567_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_f5567_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_f5567_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5567_level0_row1" class="row_heading level0 row1" >term_bool</th>
#       <td id="T_f5567_row1_col0" class="data row1 col0" >22863.000000</td>
#       <td id="T_f5567_row1_col1" class="data row1 col1" >0.048856</td>
#       <td id="T_f5567_row1_col2" class="data row1 col2" >0.215572</td>
#       <td id="T_f5567_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_f5567_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f5567_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_f5567_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_f5567_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5567_level0_row2" class="row_heading level0 row2" >gender</th>
#       <td id="T_f5567_row2_col0" class="data row2 col0" >22863.000000</td>
#       <td id="T_f5567_row2_col1" class="data row2 col1" >0.284871</td>
#       <td id="T_f5567_row2_col2" class="data row2 col2" >0.451363</td>
#       <td id="T_f5567_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_f5567_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_f5567_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_f5567_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_f5567_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5567_level0_row3" class="row_heading level0 row3" >reason</th>
#       <td id="T_f5567_row3_col0" class="data row3 col0" >22863.000000</td>
#       <td id="T_f5567_row3_col1" class="data row3 col1" >5.750864</td>
#       <td id="T_f5567_row3_col2" class="data row3 col2" >4.968358</td>
#       <td id="T_f5567_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f5567_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_f5567_row3_col5" class="data row3 col5" >5.000000</td>
#       <td id="T_f5567_row3_col6" class="data row3 col6" >8.000000</td>
#       <td id="T_f5567_row3_col7" class="data row3 col7" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5567_level0_row4" class="row_heading level0 row4" >emp_subgroup</th>
#       <td id="T_f5567_row4_col0" class="data row4 col0" >22863.000000</td>
#       <td id="T_f5567_row4_col1" class="data row4 col1" >0.477540</td>
#       <td id="T_f5567_row4_col2" class="data row4 col2" >0.499506</td>
#       <td id="T_f5567_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_f5567_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_f5567_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_f5567_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_f5567_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5567_level0_row5" class="row_heading level0 row5" >prev_wage</th>
#       <td id="T_f5567_row5_col0" class="data row5 col0" >22863.000000</td>
#       <td id="T_f5567_row5_col1" class="data row5 col1" >33476.981897</td>
#       <td id="T_f5567_row5_col2" class="data row5 col2" >44520.064330</td>
#       <td id="T_f5567_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_f5567_row5_col4" class="data row5 col4" >18.615000</td>
#       <td id="T_f5567_row5_col5" class="data row5 col5" >28.500000</td>
#       <td id="T_f5567_row5_col6" class="data row5 col6" >68940.000000</td>
#       <td id="T_f5567_row5_col7" class="data row5 col7" >662500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5567_level0_row6" class="row_heading level0 row6" >annual_salary</th>
#       <td id="T_f5567_row6_col0" class="data row6 col0" >22813.000000</td>
#       <td id="T_f5567_row6_col1" class="data row6 col1" >61226.741151</td>
#       <td id="T_f5567_row6_col2" class="data row6 col2" >30654.768289</td>
#       <td id="T_f5567_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_f5567_row6_col4" class="data row6 col4" >41412.800000</td>
#       <td id="T_f5567_row6_col5" class="data row6 col5" >55100.000000</td>
#       <td id="T_f5567_row6_col6" class="data row6 col6" >73500.000000</td>
#       <td id="T_f5567_row6_col7" class="data row6 col7" >685700.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5567_level0_row7" class="row_heading level0 row7" >percent_of_market_after_action</th>
#       <td id="T_f5567_row7_col0" class="data row7 col0" >

# %%
# df.var()

# %%
# Move churned to first column
df = df[["churned"] + [col for col in df.columns if col != "churned"]]

# %%
corr_matrix = df.corr(method="pearson", min_periods=1)
corr_matrix
# Out:
#                                   churned    reason  annl_sal_hrly_wage  \
# churned                          1.000000  0.254583           -0.153997
# reason                           0.254583  1.000000           -0.005501
# annl_sal_hrly_wage              -0.153997 -0.005501            1.000000
# annual_salary                   -0.080273 -0.012216            0.859082
# pay_level_midpoint              -0.049479  0.042226            0.860570
# prev_wage                       -0.048103  0.058381            0.936747
# pts                             -0.161285  0.014602            0.308906
# age_at_action                   -0.039817  0.093081            0.185569
# percent_of_market_after_action  -0.079492 -0.119231            0.224660
# percent_of_market_before_action -0.005570 -0.019574           -0.025864
# gender                          -0.003484 -0.008765            0.009230
# emp_subgroup                    -0.035951  0.054463            0.828906
# commission                       0.065733  0.103165           -0.086882
# fst_bool                        -0.006554 -0.016538           -0.441952
# urg_current                      0.018173 -0.006421           -0.042345
# retiree_med                     -0.004355  0.063956            0.114686
# progression_bool                -0.031361 -0.132483           -0.005214
# promotion_bool                  -0.043160 -0.212509            0.041719
# retirement_bool                  0.287632  0.233258           -0.055635
# term_bool                        0.856913  0.323297           -0.179711
# hired_bool                      -0.049355 -0.243014           -0.121960
# Time_In_TDS                     -0.076167  0.060464            0.355987
# Time_In_Payscale                -0.033603  0.092434            0.143168
# time_since_last_event           -0.174784 -0.011722            0.094057
#
#                                  annual_salary  pay_level_midpoint  prev_wage  \
# churned                              -0.080273           -0.049479  -0.048103
# reason                               -0.012216            0.042226   0.058381
# annl_sal_hrly_wage                    0.859082            0.860570   0.936747
# annual_salary                         1.000000            0.621469   0.845255
# pay_level_midpoint                    0.621469            1.000000   0.830698
# prev_wage                             0.845255            0.830698   1.000000
# pts                                   0.367336            0.277889   0.346748
# age_at_action                         0.283289            0.171595   0.205226
# percent_of_market_after_action        0.548796           -0.033867   0.224734
# percent_of_market_before_action      -0.011456           -0.029186   0.018207
# gender                               -0.070166            0.009044   0.004336
# emp_subgroup                          0.525013            0.929671   0.783654
# commission                           -0.264896            0.104899  -0.089331
# fst_bool                             -0.136769           -0.496955  -0.418748
# urg_current                          -0.124013           -0.033730  -0.047419
# retiree_med                           0.241529            0.062897   0.143059
# progression_bool                      0.007632           -0.008435  -0.006377
# promotion_bool                        0.026119            0.048984  -0.014383
# retirement_bool                      -0.005254            0.007824   0.022018
# term_bool                            -0.187717           -0.066054  -0.062730
# hired_bool                           -0.143533           -0.105553  -0.191100
# Time_In_TDS                           0.481338            0.278073   0.392592
# Time_In_Payscale                      0.280153            0.093000   0.190478
# time_since_last_event                 0.126387            0.059215   0.068361
#
#                                       pts  age_at_action  \
# churned                         -0.161285      -0.039817
# reason                           0.014602       0.093081
# annl_sal_hrly_wage               0.308906       0.185569
# annual_salary                    0.367336       0.283289
# pay_level_midpoint               0.277889       0.171595
# prev_wage                        0.346748       0.205226
# pts                              1.000000       0.253523
# age_at_action                    0.253523       1.000000
# percent_of_market_after_action   0.264483       0.162290
# percent_of_market_before_action  0.009106       0.015007
# gender                           0.012991       0.096323
# emp_subgroup                     0.235628       0.118239
# commission                      -0.053768       0.005613
# fst_bool                        -0.016164       0.010702
# urg_current                     -0.054474       0.019695
# retiree_med                      0.139684       0.518313
# progression_bool                 0.049581      -0.065288
# promotion_bool                   0.072871      -0.050273
# retirement_bool                  0.013596       0.120369
# term_bool                       -0.189319      -0.048800
# hired_bool                      -0.490069      -0.152250
# Time_In_TDS                      0.361119       0.532864
# Time_In_Payscale                 0.223808       0.428737
# time_since_last_event            0.076554       0.090366
#
#                                  percent_of_market_after_action  \
# churned                                               -0.079492
# reason                                                -0.119231
# annl_sal_hrly_wage                                     0.224660
# annual_salary                                          0.548796
# pay_level_midpoint                                    -0.033867
# prev_wage                                              0.224734
# pts                                                    0.264483
# age_at_action                                          0.162290
# percent_of_market_after_action                         1.000000
# percent_of_market_before_action                        0.021412
# gender                                                -0.003670
# emp_subgroup                                          -0.080872
# commission                                            -0.579006
# fst_bool                                               0.132124
# urg_current                                           -0.040683
# retiree_med                                            0.222055
# progression_bool                                       0.006257
# promotion_bool                                        -0.029461
# retirement_bool                                       -0.035530
# term_bool                                             -0.331286
# hired_bool                                            -0.113326
# Time_In_TDS                                            0.363798
# Time_In_Payscale                                       0.313243
# time_since_last_event                                  0.127825
#
#                                  percent_of_market_before_action    gender  \
# churned                                                -0.005570 -0.003484
# reason                                                 -0.019574 -0.008765
# annl_sal_hrly_wage                                     -0.025864  0.009230
# annual_salary                                          -0.011456 -0.070166
# pay_level_midpoint                                     -0.029186  0.009044
# prev_wage                                               0.018207  0.004336
# pts                                                     0.009106  0.012991
# age_at_action                                           0.015007  0.096323
# percent_of_market_after_action                          0.021412 -0.003670
# percent_of_market_before_action                         1.000000 -0.013969
# gender                                                 -0.013969  1.000000
# emp_subgroup                                           -0.031142  0.025373
# commission                                             -0.005028  0.095232
# fst_bool                                                0.017278 -0.339277
# urg_current                                            -0.016271  0.809259
# retiree_med                                             0.018158  0.013627
# progression_bool                                       -0.005087 -0.061275
# promotion_bool                                         -0.007531 -0.027694
# retirement_bool                                        -0.001980 -0.006809
# term_bool                                              -0.006547 -0.001888
# hired_bool                                             -0.009817 -0.003295
# Time_In_TDS                                             0.004468  0.037635
# Time_In_Payscale                                       -0.019775 -0.004633
# time_since_last_event                                  -0.006066 -0.014268
#
#                                  emp_subgroup  commission  fst_bool  \
# churned                             -0.035951    0.065733 -0.006554
# reason                               0.054463    0.103165 -0.016538
# annl_sal_hrly_wage                   0.828906   -0.086882 -0.441952
# annual_salary                        0.525013   -0.264896 -0.136769
# pay_level_midpoint                   0.929671    0.104899 -0.496955
# prev_wage                            0.783654   -0.089331 -0.418748
# pts                                  0.235628   -0.053768 -0.016164
# age_at_action                        0.118239    0.005613  0.010702
# percent_of_market_after_action      -0.080872   -0.579006  0.132124
# percent_of_market_before_action     -0.031142   -0.005028  0.017278
# gender                               0.025373    0.095232 -0.339277
# emp_subgroup                         1.000000    0.133543 -0.532958
# commission                           0.133543    1.000000 -0.184963
# fst_bool                            -0.532958   -0.184963  1.000000
# urg_current                         -0.012151    0.098842 -0.273288
# retiree_med                          0.021726   -0.095933  0.077155
# progression_bool                    -0.009710   -0.055268  0.074773
# promotion_bool                       0.047620   -0.049118 -0.008875
# retirement_bool                      0.001901   -0.021211  0.007826
# term_bool                           -0.048913    0.083526 -0.010989
# hired_bool                          -0.104305    0.051346  0.038975
# Time_In_TDS                          0.207948   -0.168974 -0.018459
# Time_In_Payscale                     0.046669   -0.090574  0.119933
# time_since_last_event                0.040107   -0.066920  0.040931
#
#                                  urg_current  retiree_med  progression_bool  \
# churned                             0.018173    -0.004355         -0.031361
# reason                             -0.006421     0.063956         -0.132483
# annl_sal_hrly_wage                 -0.042345     0.114686         -0.005214
# annual_salary                      -0.124013     0.241529          0.007632
# pay_level_midpoint                 -0.033730     0.062897         -0.008435
# prev_wage                          -0.047419     0.143059         -0.006377
# pts                                -0.054474     0.139684          0.049581
# age_at_action                       0.019695     0.518313         -0.065288
# percent_of_market_after_action     -0.040683     0.222055          0.006257
# percent_of_market_before_action    -0.016271     0.018158         -0.005087
# gender                              0.809259     0.013627         -0.061275
# emp_subgroup                       -0.012151     0.021726         -0.009710
# commission                          0.098842    -0.095933         -0.055268
# fst_bool                           -0.273288     0.077155          0.074773
# urg_current                         1.000000    -0.025815         -0.056017
# retiree_med                        -0.025815     1.000000         -0.033993
# progression_bool                   -0.056017    -0.033993          1.000000
# promotion_bool                     -0.027664    -0.044751          0.563877
# retirement_bool                    -0.015966     0.194191         -0.011330
# term_bool                           0.022820    -0.010781         -0.036597
# hired_bool                          0.027364    -0.090674         -0.041037
# Time_In_TDS                        -0.041163     0.615861         -0.050103
# Time_In_Payscale                   -0.056592     0.480740         -0.103631
# time_since_last_event              -0.026986     0.059058          0.023874
#
#                                  promotion_bool  retirement_bool  term_bool  \
# churned                               -0.043160         0.287632   0.856913
# reason                                -0.212509         0.233258   0.323297
# annl_sal_hrly_wage                     0.041719        -0.055635  -0.179711
# annual_salary                          0.026119        -0.005254  -0.187717
# pay_level_midpoint                     0.048984         0.007824  -0.066054
# prev_wage                             -0.014383         0.022018  -0.062730
# pts                                    0.072871         0.013596  -0.189319
# age_at_action                         -0.050273         0.120369  -0.048800
# percent_of_market_after_action        -0.029461        -0.035530  -0.331286
# percent_of_market_before_action       -0.007531        -0.001980  -0.006547
# gender                                -0.027694        -0.006809  -0.001888
# emp_subgroup                           0.047620         0.001901  -0.048913
# commission                            -0.049118        -0.021211   0.083526
# fst_bool                              -0.008875         0.007826  -0.010989
# urg_current                           -0.027664        -0.015966   0.022820
# retiree_med                           -0.044751         0.194191  -0.010781
# progression_bool                       0.563877        -0.011330  -0.036597
# promotion_bool                         1.000000        -0.015593  -0.050367
# retirement_bool                       -0.015593         1.000000   0.309579
# term_bool                             -0.050367         0.309579   1.000000
# hired_bool                            -0.056477        -0.017831  -0.057597
# Time_In_TDS                           -0.040552         0.127567  -0.090227
# Time_In_Payscale                      -0.147094         0.108895  -0.039602
# time_since_last_event                  0.041161        -0.065565  -0.204863
#
#                                  hired_bool  Time_In_TDS  Time_In_Payscale  \
# churned                           -0.049355    -0.076167         -0.033603
# reason                            -0.243014     0.060464          0.092434
# annl_sal_hrly_wage                -0.121960     0.355987          0.143168
# annual_salary                     -0.143533     0.481338          0.280153
# pay_level_midpoint                -0.105553     0.278073          0.093000
# prev_wage                         -0.191100     0.392592          0.190478
# pts                               -0.490069     0.361119          0.223808
# age_at_action                     -0.152250     0.532864          0.428737
# percent_of_market_after_action    -0.113326     0.363798          0.313243
# percent_of_market_before_action   -0.009817     0.004468         -0.019775
# gender                            -0.003295     0.037635         -0.004633
# emp_subgroup                      -0.104305     0.207948          0.046669
# commission                         0.051346    -0.168974         -0.090574
# fst_bool                           0.038975    -0.018459          0.119933
# urg_current                        0.027364    -0.041163         -0.056592
# retiree_med                       -0.090674     0.615861          0.480740
# progression_bool                  -0.041037    -0.050103         -0.103631
# promotion_bool                    -0.056477    -0.040552         -0.147094
# retirement_bool                   -0.017831     0.127567          0.108895
# term_bool                         -0.057597    -0.090227         -0.039602
# hired_bool                         1.000000    -0.215008         -0.164931
# Time_In_TDS                       -0.215008     1.000000          0.662130
# Time_In_Payscale                  -0.164931     0.662130          1.000000
# time_since_last_event             -0.000857     0.153854          0.146004
#
#                                  time_since_last_event
# churned                                      -0.174784
# reason                                       -0.011722
# annl_sal_hrly_wage                            0.094057
# annual_salary                                 0.126387
# pay_level_midpoint                            0.059215
# prev_wage                                     0.068361
# pts                                           0.076554
# age_at_action                                 0.090366
# percent_of_market_after_action                0.127825
# percent_of_market_before_action              -0.006066
# gender                                       -0.014268
# emp_subgroup                                  0.040107
# commission                                   -0.066920
# fst_bool                                      0.040931
# urg_current                                  -0.026986
# retiree_med                                   0.059058
# progression_bool                              0.023874
# promotion_bool                                0.041161
# retirement_bool                              -0.065565
# term_bool                                    -0.204863
# hired_bool                                   -0.000857
# Time_In_TDS                                   0.153854
# Time_In_Payscale                              0.146004
# time_since_last_event                         1.000000

# %%
_ = plt.figure(figsize=(64, 20))

filtered = corr_matrix[
    ((corr_matrix >= 0.3) | (corr_matrix <= -0.3)) & (corr_matrix != 1)
]

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
# f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

g = sns.heatmap(
    filtered,
    # corr_matrix,
    mask=mask,
    cmap=cmap,
    # vmax=0.3,
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.5},
    annot=True,
)

_ = g.set_xticklabels(g.get_xticklabels(), rotation=80)

# %%
# drop unnecessary & leaky features
df = df.drop(
    columns=[
        "annl_sal_hrly_wage",
        "pay_level_midpoint",
        "generation",
        "reason",
        "employee_group",
        "retirement_bool",
        "term_bool",
        # "Time_In_Team",
    ]
)

# %%
df[df["churned"] == 1].count()
# Out:
# churned                                831
# pers_no                                831
# job_key                                831
# position                               831
# job_abbrev                             831
# contract                               831
# act                                    831
# start_date                             831
# most_recent_hire_date_01               831
# service_anniversary_16                 831
# cocd                                   831
# org_unit                               831
# pay_scale_group_effective_date         831
# ps_group                               831
# prev_ps_group                          831
# annual_salary                          781
# prev_wage                              831
# pts                                    831
# supervisor                             826
# ps_area                                831
# aap                                    819
# city                                   831
# state                                  831
# functional_area                        831
# age_at_action                          831
# percent_of_market_after_action         681
# percent_of_market_before_action        681
# previous_job_code                      831
# current_bu                             831
# previous_bu                            831
# race_ethinicity_most_current           831
# poc_non_poc_most_current               831
# disabled_most_current                  831
# tds_vet_excludes_v1_v9_most_current    831
# gender                                 831
# emp_subgroup                           831
# commission                             831
# fst_bool                               831
# urg_current                            831
# retiree_med                            831
# progression_bool                       831
# promotion_bool                         831
# hired_bool                             831
# Time_In_TDS                            831
# Time_In_Payscale                       831
# time_since_last_event                  831
# dtype: int64

# %%
df = df.dropna()

# %%
df.reset_index(drop=True).to_parquet(os.path.join(path, "df.parquet"))
